# %% [markdown]
# **My Jupyter Notebook on IBM Watson Studio**

# %% [markdown]
# **PRABHAT DHINGRA**
#
# Data Scientist

# %% [markdown]
# *I want to be a data scientist because of my good
# analytical skills and curiosity towards data driven world.
# I want to be involved in healthcare industry as a data scientist.*

# %% [markdown]
# **The below should print "Good Day!"**

# %%
print("Good Day!")
# Out:
# Good Day!
